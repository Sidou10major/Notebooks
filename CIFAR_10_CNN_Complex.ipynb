# %% [markdown]
# ## Split CIFAR-10 into training, validation, and testing sets

# %%
import torch
import torchvision
import torchvision.transforms as transforms

train_transform = transforms.Compose(
    [transforms.RandomHorizontalFlip(p=0.5),
     transforms.RandomAffine(degrees=(-5, 5), translate=(0.1, 0.1), scale=(0.9, 1.1)),
     transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

test_transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=train_transform)
train_set, val_set = torch.utils.data.random_split(dataset, [40000, 10000])

train_loader = torch.utils.data.DataLoader(train_set, batch_size=128, shuffle=True, num_workers=8)
val_loader = torch.utils.data.DataLoader(val_set, batch_size=128, shuffle=False, num_workers=8)

test_set = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=test_transform)
test_loader = torch.utils.data.DataLoader(test_set, batch_size=128, shuffle=False, num_workers=8)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:03<00:00, 42881550.70it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Files already downloaded and verified

# %% [markdown]
# ## Visualize image for each class

# %%
import matplotlib.pyplot as plt
import numpy as np

# visualize training image for each class
sample_images = [dataset.data[np.asarray(dataset.targets) == label][0] for label in range(10)]
# show images
fig, axes = plt.subplots(2, 5, figsize=(12, 6))
i = 0
for row in axes:
  for axis in row:
    axis.set_xticks([])
    axis.set_yticks([])
    axis.set_xlabel(classes[i], fontsize=15)
    axis.imshow(sample_images[i])
    i += 1

# %% [markdown]
# ## Define CNN architecture

# %%
import torch.nn as nn
import torch.nn.functional as F

class Net(nn.Module):
  def __init__(self):
    super(Net, self).__init__()
    self.conv1 = nn.Conv2d(3, 128, 5, padding=2)
    self.conv2 = nn.Conv2d(128, 128, 5, padding=2)
    self.conv3 = nn.Conv2d(128, 256, 3, padding=1)
    self.conv4 = nn.Conv2d(256, 256, 3, padding=1)
    self.pool = nn.MaxPool2d(2, 2)
    self.bn_conv1 = nn.BatchNorm2d(128)
    self.bn_conv2 = nn.BatchNorm2d(128)
    self.bn_conv3 = nn.BatchNorm2d(256)
    self.bn_conv4 = nn.BatchNorm2d(256)
    self.bn_dense1 = nn.BatchNorm1d(1024)
    self.bn_dense2 = nn.BatchNorm1d(512)
    self.dropout_conv = nn.Dropout2d(p=0.25)
    self.dropout = nn.Dropout(p=0.5)
    self.fc1 = nn.Linear(256 * 8 * 8, 1024)
    self.fc2 = nn.Linear(1024, 512)
    self.fc3 = nn.Linear(512, 10)

  def conv_layers(self, x):
    out = F.relu(self.bn_conv1(self.conv1(x)))
    out = F.relu(self.bn_conv2(self.conv2(out)))
    out = self.pool(out)
    out = self.dropout_conv(out)
    out = F.relu(self.bn_conv3(self.conv3(out)))
    out = F.relu(self.bn_conv4(self.conv4(out)))
    out = self.pool(out)
    out = self.dropout_conv(out)
    return out

  def dense_layers(self, x):
    out = F.relu(self.bn_dense1(self.fc1(x)))
    out = self.dropout(out)
    out = F.relu(self.bn_dense2(self.fc2(out)))
    out = self.dropout(out)
    out = self.fc3(out)
    return out

  def forward(self, x):
    out = self.conv_layers(x)
    out = out.view(-1, 256 * 8 * 8)
    out = self.dense_layers(out)
    return out

net = Net()
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print('Device:', device)
net.to(device)

num_params = sum(p.numel() for p in net.parameters() if p.requires_grad)
print("Number of trainable parameters:", num_params)
# Out:
# Device: cuda:0
# Number of trainable parameters: 18617482

# %% [markdown]
# ## Training

# %%
import torch.optim as optim

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=0.01, betas=(0.9, 0.999), eps=1e-08, weight_decay=0, amsgrad=False)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=10, verbose=True, min_lr=0)

loss_hist, acc_hist = [], []
loss_hist_val, acc_hist_val = [], []

for epoch in range(140):
  running_loss = 0.0
  correct = 0
  for data in train_loader:
    batch, labels = data
    batch, labels = batch.to(device), labels.to(device)

    optimizer.zero_grad()
    outputs = net(batch)
    loss = criterion(outputs, labels)
    loss.backward()
    optimizer.step()

    # compute training statistics
    _, predicted = torch.max(outputs, 1)
    correct += (predicted == labels).sum().item()
    running_loss += loss.item()

  avg_loss = running_loss / len(train_set)
  avg_acc = correct / len(train_set)
  loss_hist.append(avg_loss)
  acc_hist.append(avg_acc)

  # validation statistics
  net.eval()
  with torch.no_grad():
    loss_val = 0.0
    correct_val = 0
    for data in val_loader:
      batch, labels = data
      batch, labels = batch.to(device), labels.to(device)
      outputs = net(batch)
      loss = criterion(outputs, labels)
      _, predicted = torch.max(outputs, 1)
      correct_val += (predicted == labels).sum().item()
      loss_val += loss.item()
    avg_loss_val = loss_val / len(val_set)
    avg_acc_val = correct_val / len(val_set)
    loss_hist_val.append(avg_loss_val)
    acc_hist_val.append(avg_acc_val)
  net.train()

  scheduler.step(avg_loss_val)
  print('[epoch %d] loss: %.5f accuracy: %.4f val loss: %.5f val accuracy: %.4f' % (epoch + 1, avg_loss, avg_acc, avg_loss_val, avg_acc_val))
# Out:
# [epoch 1] loss: 0.01402 accuracy: 0.3513 val loss: 0.01162 val accuracy: 0.4565
# [epoch 2] loss: 0.01152 accuracy: 0.4647 val loss: 0.01019 val accuracy: 0.5279
# [epoch 3] loss: 0.00986 accuracy: 0.5492 val loss: 0.00857 val accuracy: 0.6166
# [epoch 4] loss: 0.00869 accuracy: 0.6072 val loss: 0.00763 val accuracy: 0.6616
# [epoch 5] loss: 0.00791 accuracy: 0.6458 val loss: 0.00665 val accuracy: 0.7047
# [epoch 6] loss: 0.00733 accuracy: 0.6703 val loss: 0.00624 val accuracy: 0.7218
# [epoch 7] loss: 0.00691 accuracy: 0.6932 val loss: 0.00613 val accuracy: 0.7266
# [epoch 8] loss: 0.00655 accuracy: 0.7080 val loss: 0.00562 val accuracy: 0.7501
# [epoch 9] loss: 0.00627 accuracy: 0.7249 val loss: 0.00514 val accuracy: 0.7712
# [epoch 10] loss: 0.00610 accuracy: 0.7325 val loss: 0.00511 val accuracy: 0.7726
# [epoch 11] loss: 0.00583 accuracy: 0.7430 val loss: 0.00493 val accuracy: 0.7804
# [epoch 12] loss: 0.00569 accuracy: 0.7512 val loss: 0.00466 val accuracy: 0.7941
# [epoch 13] loss: 0.00544 accuracy: 0.7614 val loss: 0.00485 val accuracy: 0.7901
# [epoch 14] loss: 0.00534 accuracy: 0.7635 val loss: 0.00455 val accuracy: 0.8009
# [epoch 15] loss: 0.00514 accuracy: 0.7765 val loss: 0.00437 val accuracy: 0.8144
# [epoch 16] loss: 0.00503 accuracy: 0.7785 val loss: 0.00398 val accuracy: 0.8262
# [epoch 17] loss: 0.00493 accuracy: 0.7840 val loss: 0.00395 val accuracy: 0.8273
# [epoch 18] loss: 0.00481 accuracy: 0.7914 val loss: 0.00389 val accuracy: 0.8280
# [epoch 19] loss: 0.00463 accuracy: 0.7968 val loss: 0.00388 val accuracy: 0.8288
# [epoch 20] loss: 0.00455 accuracy: 0.8011 val loss: 0.00397 val accuracy: 0.8206
# [epoch 21] loss: 0.00440 accuracy: 0.8072 val loss: 0.00383 val accuracy: 0.8307
# [epoch 22] loss: 0.00431 accuracy: 0.8144 val loss: 0.00377 val accuracy: 0.8342
# [epoch 23] loss: 0.00428 accuracy: 0.8125 val loss: 0.00370 val accuracy: 0.8390
# [epoch 24] loss: 0.00422 accuracy: 0.8151 val loss: 0.00349 val accuracy: 0.8449
# [epoch 25] loss: 0.00411 accuracy: 0.8209 val loss: 0.00344 val accuracy: 0.8490
# [epoch 26] loss: 0.00401 accuracy: 0.8241 val loss: 0.00359 val accuracy: 0.8436
# [epoch 27] loss: 0.00399 accuracy: 0.8279 val loss: 0.00331 val accuracy: 0.8488
# [epoch 28] loss: 0.00392 accuracy: 0.8322 val loss: 0.00331 val accuracy: 0.8553
# [epoch 29] loss: 0.00385 accuracy: 0.8354 val loss: 0.00339 val accuracy: 0.8496
# [epoch 30] loss: 0.00377 accuracy: 0.8342 val loss: 0.00331 val accuracy: 0.8553
# [epoch 31] loss: 0.00368 accuracy: 0.8387 val loss: 0.00329 val accuracy: 0.8580
# [epoch 32] loss: 0.00369 accuracy: 0.8400 val loss: 0.00318 val accuracy: 0.8590
# [epoch 33] loss: 0.00353 accuracy: 0.8452 val loss: 0.00316 val accuracy: 0.8597
# [epoch 34] loss: 0.00354 accuracy: 0.8430 val loss: 0.00313 val accuracy: 0.8622
# [epoch 35] loss: 0.00346 accuracy: 0.8516 val loss: 0.00326 val accuracy: 0.8551
# [epoch 36] loss: 0.00340 accuracy: 0.8525 val loss: 0.00333 val accuracy: 0.8560
# [epoch 37] loss: 0.00336 accuracy: 0.8544 val loss: 0.00306 val accuracy: 0.8678
# [epoch 38] loss: 0.00331 accuracy: 0.8562 val loss: 0.00300 val accuracy: 0.8705
# [epoch 39] loss: 0.00328 accuracy: 0.8593 val loss: 0.00310 val accuracy: 0.8658
# [epoch 40] loss: 0.00322 accuracy: 0.8597 val loss: 0.00297 val accuracy: 0.8721
# [epoch 41] loss: 0.00320 accuracy: 0.8581 val loss: 0.00302 val accuracy: 0.8694
# [epoch 42] loss: 0.00317 accuracy: 0.8608 val loss: 0.00287 val accuracy: 0.8715
# [epoch 43] loss: 0.00310 accuracy: 0.8638 val loss: 0.00297 val accuracy: 0.8718
# [epoch 44] loss: 0.00312 accuracy: 0.8651 val loss: 0.00295 val accuracy: 0.8710
# [epoch 45] loss: 0.00310 accuracy: 0.8656 val loss: 0.00294 val accuracy: 0.8710
# [epoch 46] loss: 0.00303 accuracy: 0.8694 val loss: 0.00308 val accuracy: 0.8654
# [epoch 47] loss: 0.00293 accuracy: 0.8707 val loss: 0.00300 val accuracy: 0.8726
# [epoch 48] loss: 0.00295 accuracy: 0.8714 val loss: 0.00288 val accuracy: 0.8762
# [epoch 49] loss: 0.00287 accuracy: 0.8752 val loss: 0.00284 val accuracy: 0.8760
# [epoch 50] loss: 0.00285 accuracy: 0.8771 val loss: 0.00290 val accuracy: 0.8796
# [epoch 51] loss: 0.00291 accuracy: 0.8739 val loss: 0.00282 val accuracy: 0.8788
# [epoch 52] loss: 0.00284 accuracy: 0.8785 val loss: 0.00304 val accuracy: 0.8727
# [epoch 53] loss: 0.00281 accuracy: 0.8768 val loss: 0.00276 val accuracy: 0.8763
# [epoch 54] loss: 0.00266 accuracy: 0.8836 val loss: 0.00302 val accuracy: 0.8717
# [epoch 55] loss: 0.00271 accuracy: 0.8822 val loss: 0.00281 val accuracy: 0.8808
# [epoch 56] loss: 0.00269 accuracy: 0.8820 val loss: 0.00289 val accuracy: 0.8753
# [epoch 57] loss: 0.00266 accuracy: 0.8840 val loss: 0.00290 val accuracy: 0.8781
# [epoch 58] loss: 0.00260 accuracy: 0.8833 val loss: 0.00267 val accuracy: 0.8852
# [epoch 59] loss: 0.00261 accuracy: 0.8861 val loss: 0.00282 val accuracy: 0.8761
# [epoch 60] loss: 0.00259 accuracy: 0.8864 val loss: 0.00288 val accuracy: 0.8778
# [epoch 61] loss: 0.00255 accuracy: 0.8885 val loss: 0.00277 val accuracy: 0.8820
# [epoch 62] loss: 0.00255 accuracy: 0.8871 val loss: 0.00279 val accuracy: 0.8800
# [epoch 63] loss: 0.00254 accuracy: 0.8898 val loss: 0.00282 val accuracy: 0.8800
# [epoch 64] loss: 0.00247 accuracy: 0.8927 val loss: 0.00281 val accuracy: 0.8838
# [epoch 65] loss: 0.00250 accuracy: 0.8894 val loss: 0.00272 val accuracy: 0.8839
# [epoch 66] loss: 0.00249 accuracy: 0.8915 val loss: 0.00274 val accuracy: 0.8873
# [epoch 67] loss: 0.00246 accuracy: 0.8918 val loss: 0.00261 val accuracy: 0.8903
# [epoch 68] loss: 0.00240 accuracy: 0.8969 val loss: 0.00276 val accuracy: 0.8822
# [epoch 69] loss: 0.00239 accuracy: 0.8976 val loss: 0.00278 val accuracy: 0.8856
# [epoch 70] loss: 0.00237 accuracy: 0.8964 val loss: 0.00271 val accuracy: 0.8868
# [epoch 71] loss: 0.00236 accuracy: 0.8984 val loss: 0.00275 val accuracy: 0.8814
# [epoch 72] loss: 0.00232 accuracy: 0.9000 val loss: 0.00261 val accuracy: 0.8891
# [epoch 73] loss: 0.00230 accuracy: 0.8998 val loss: 0.00260 val accuracy: 0.8890
# [epoch 74] loss: 0.00228 accuracy: 0.9009 val loss: 0.00274 val accuracy: 0.8858
# [epoch 75] loss: 0.00230 accuracy: 0.8992 val loss: 0.00271 val accuracy: 0.8885
# [epoch 76] loss: 0.00230 accuracy: 0.8985 val loss: 0.00277 val accuracy: 0.8829
# [epoch 77] loss: 0.00222 accuracy: 0.9034 val loss: 0.00265 val accuracy: 0.8892
# [epoch 78] loss: 0.00220 accuracy: 0.9061 val loss: 0.00260 val accuracy: 0.8894
# [epoch 79] loss: 0.00219 accuracy: 0.9030 val loss: 0.00260 val accuracy: 0.8901
# [epoch 80] loss: 0.00218 accuracy: 0.9069 val loss: 0.00262 val accuracy: 0.8918
# [epoch 81] loss: 0.00217 accuracy: 0.9038 val loss: 0.00263 val accuracy: 0.8918
# [epoch 82] loss: 0.00216 accuracy: 0.9070 val loss: 0.00260 val accuracy: 0.8878
# [epoch 83] loss: 0.00218 accuracy: 0.9056 val loss: 0.00267 val accuracy: 0.8908
# [epoch 84] loss: 0.00216 accuracy: 0.9042 val loss: 0.00268 val accuracy: 0.8877
# [epoch 85] loss: 0.00210 accuracy: 0.9068 val loss: 0.00258 val accuracy: 0.8906
# [epoch 86] loss: 0.00212 accuracy: 0.9071 val loss: 0.00265 val accuracy: 0.8925
# [epoch 87] loss: 0.00210 accuracy: 0.9080 val loss: 0.00273 val accuracy: 0.8847
# [epoch 88] loss: 0.00205 accuracy: 0.9100 val loss: 0.00256 val accuracy: 0.8937
# [epoch 89] loss: 0.00203 accuracy: 0.9097 val loss: 0.00262 val accuracy: 0.8957
# [epoch 90] loss: 0.00205 accuracy: 0.9105 val loss: 0.00266 val accuracy: 0.8927
# [epoch 91] loss: 0.00201 accuracy: 0.9130 val loss: 0.00273 val accuracy: 0.8890
# [epoch 92] loss: 0.00196 accuracy: 0.9142 val loss: 0.00267 val accuracy: 0.8929
# [epoch 93] loss: 0.00202 accuracy: 0.9129 val loss: 0.00266 val accuracy: 0.8853
# [epoch 94] loss: 0.00198 accuracy: 0.9144 val loss: 0.00263 val accuracy: 0.8952
# [epoch 95] loss: 0.00199 accuracy: 0.9164 val loss: 0.00261 val accuracy: 0.8920
# [epoch 96] loss: 0.00198 accuracy: 0.9136 val loss: 0.00260 val accuracy: 0.8908
# [epoch 97] loss: 0.00196 accuracy: 0.9153 val loss: 0.00252 val accuracy: 0.8977
# [epoch 98] loss: 0.00192 accuracy: 0.9173 val loss: 0.00262 val accuracy: 0.8949
# [epoch 99] loss: 0.00191 accuracy: 0.9161 val loss: 0.00271 val accuracy: 0.8936
# [epoch 100] loss: 0.00188 accuracy: 0.9175 val loss: 0.00263 val accuracy: 0.8915
# [epoch 101] loss: 0.00191 accuracy: 0.9182 val loss: 0.00271 val accuracy: 0.8916
# [epoch 102] loss: 0.00190 accuracy: 0.9177 val loss: 0.00268 val accuracy: 0.8922
# [epoch 103] loss: 0.00187 accuracy: 0.9180 val loss: 0.00269 val accuracy: 0.8906
# [epoch 104] loss: 0.00190 accuracy: 0.9165 val loss: 0.00259 val accuracy: 0.8937
# [epoch 105] loss: 0.00181 accuracy: 0.9218 val loss: 0.00270 val accuracy: 0.8936
# [epoch 106] loss: 0.00186 accuracy: 0.9199 val loss: 0.00258 val accuracy: 0.8914
# [epoch 107] loss: 0.00185 accuracy: 0.9183 val loss: 0.00254 val accuracy: 0.8948
# Epoch 00108: reducing learning rate of group 0 to 1.0000e-03.
# [epoch 108] loss: 0.00185 accuracy: 0.9200 val loss: 0.00258 val accuracy: 0.8945
# [epoch 109] loss: 0.00162 accuracy: 0.9295 val loss: 0.00245 val accuracy: 0.8986
# [epoch 110] loss: 0.00149 accuracy: 0.9356 val loss: 0.00241 val accuracy: 0.9062
# [epoch 111] loss: 0.00143 accuracy: 0.9381 val loss: 0.00242 val accuracy: 0.9035
# [epoch 112] loss: 0.00135 accuracy: 0.9426 val loss: 0.00246 val accuracy: 0.9022
# [epoch 113] loss: 0.00136 accuracy: 0.9410 val loss: 0.00243 val accuracy: 0.9040
# [epoch 114] loss: 0.00130 accuracy: 0.9437 val loss: 0.00244 val accuracy: 0.9052
# [epoch 115] loss: 0.00132 accuracy: 0.9415 val loss: 0.00244 val accuracy: 0.9030
# [epoch 116] loss: 0.00127 accuracy: 0.9445 val loss: 0.00249 val accuracy: 0.9026
# [epoch 117] loss: 0.00127 accuracy: 0.9456 val loss: 0.00245 val accuracy: 0.9070
# [epoch 118] loss: 0.00127 accuracy: 0.9451 val loss: 0.00243 val accuracy: 0.9029
# [epoch 119] loss: 0.00127 accuracy: 0.9448 val loss: 0.00237 val accuracy: 0.9061
# [epoch 120] loss: 0.00123 accuracy: 0.9470 val loss: 0.00240 val accuracy: 0.9066
# [epoch 121] loss: 0.00120 accuracy: 0.9472 val loss: 0.00229 val accuracy: 0.9098
# [epoch 122] loss: 0.00123 accuracy: 0.9466 val loss: 0.00238 val accuracy: 0.9062
# [epoch 123] loss: 0.00116 accuracy: 0.9495 val loss: 0.00246 val accuracy: 0.9059
# [epoch 124] loss: 0.00117 accuracy: 0.9482 val loss: 0.00244 val accuracy: 0.9074
# [epoch 125] loss: 0.00116 accuracy: 0.9494 val loss: 0.00243 val accuracy: 0.9067
# [epoch 126] loss: 0.00115 accuracy: 0.9487 val loss: 0.00233 val accuracy: 0.9072
# [epoch 127] loss: 0.00114 accuracy: 0.9497 val loss: 0.00243 val accuracy: 0.9060
# [epoch 128] loss: 0.00121 accuracy: 0.9478 val loss: 0.00238 val accuracy: 0.9081
# [epoch 129] loss: 0.00114 accuracy: 0.9503 val loss: 0.00235 val accuracy: 0.9114
# [epoch 130] loss: 0.00113 accuracy: 0.9504 val loss: 0.00235 val accuracy: 0.9085
# [epoch 131] loss: 0.00113 accuracy: 0.9506 val loss: 0.00242 val accuracy: 0.9074
# Epoch 00132: reducing learning rate of group 0 to 1.0000e-04.
# [epoch 132] loss: 0.00112 accuracy: 0.9508 val loss: 0.00243 val accuracy: 0.9085
# [epoch 133] loss: 0.00111 accuracy: 0.9514 val loss: 0.00236 val accuracy: 0.9091
# [epoch 134] loss: 0.00109 accuracy: 0.9521 val loss: 0.00237 val accuracy: 0.9102
# [epoch 135] loss: 0.00113 accuracy: 0.9513 val loss: 0.00237 val accuracy: 0.9083
# [epoch 136] loss: 0.00112 accuracy: 0.9510 val loss: 0.00242 val accuracy: 0.9062
# [epoch 137] loss: 0.00111 accuracy: 0.9515 val loss: 0.00243 val accuracy: 0.9081
# [epoch 138] loss: 0.00110 accuracy: 0.9517 val loss: 0.00236 val accuracy: 0.9089
# [epoch 139] loss: 0.00111 accuracy: 0.9523 val loss: 0.00238 val accuracy: 0.9057
# [epoch 140] loss: 0.00108 accuracy: 0.9525 val loss: 0.00241 val accuracy: 0.9099

# %% [markdown]
# ## Plotting training statistics

# %%
import matplotlib.pyplot as plt

legend = ['Train', 'Validation']
plt.plot(loss_hist)
plt.plot(loss_hist_val)
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(legend, loc='upper left')
plt.show()

legend = ['Train', 'Validation']
plt.plot(acc_hist)
plt.plot(acc_hist_val)
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(legend, loc='upper left')
plt.show()

# %% [markdown]
# ## Save the trained model

# %%
from google.colab import files

torch.save(net.state_dict(), 'checkpoint.pth')
# download checkpoint file
files.download('checkpoint.pth')

# %%
net.load_state_dict(torch.load('checkpoint.pth'))
# Out:
# <All keys matched successfully>

# %% [markdown]
# ## Testing

# %%
pred_vec = []
correct = 0
net.eval()
with torch.no_grad():
    for data in test_loader:
        batch, labels = data
        batch, labels = batch.to(device), labels.to(device)
        outputs = net(batch)
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == labels).sum().item()
        pred_vec.append(predicted)
    pred_vec = torch.cat(pred_vec)

print('Accuracy on the 10000 test images: %.2f %%' % (100 * correct / len(test_set)))
# Out:
# Accuracy on the 10000 test images: 91.69 %

# %% [markdown]
# ## Visualize wrongly classified image for each class

# %%
import numpy as np

# visualize wrongly classified image for each class
pred_vec = pred_vec.cpu().numpy()
ground_truths = np.asarray(test_set.targets)
incorrect_mask = pred_vec != ground_truths
incorrect_images = [test_set.data[(ground_truths == label) & incorrect_mask][0] for label in range(10)]
pred_results = [pred_vec[(ground_truths == label) & incorrect_mask][0] for label in range(10)]

# show images
fig, axes = plt.subplots(2, 5, figsize=(12, 6))
i = 0
for row in axes:
  for axis in row:
    axis.set_xticks([])
    axis.set_yticks([])
    axis.set_xlabel("Predicted: %s" % classes[pred_results[i]], fontsize=14)
    axis.imshow(incorrect_images[i])
    i += 1
